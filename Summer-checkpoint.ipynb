# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("summer.csv")

# %%
df["City"].unique().shape
# Out:
# (22,)

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df[df['Medal']=="Gold"].Sport.value_counts().head().plot(x = 'Sport', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df.Sport.value_counts().head()
# Out:
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %%
df.Sport.value_counts().head().plot(x = 'Sport', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df.Athlete.value_counts().head()
# Out:
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Athlete, dtype: int64

# %%
df.Athlete.value_counts().head().plot(x = 'Athlete', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df[df.Medal=="Gold"].Athlete.value_counts().head()
# Out:
# PHELPS, Michael     18
# NURMI, Paavo         9
# LATYNINA, Larisa     9
# SPITZ, Mark          9
# LEWIS, Carl          9
# Name: Athlete, dtype: int64

# %%
df[df.Medal=="Gold"].Athlete.value_counts().head().plot(x = 'Athlete', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df2=df[df.Medal=="Gold"]
min(df2[df2.Country=="IND"].Year)
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df["Event"].value_counts().head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
df["Event"].value_counts().head().plot(x = 'Event', y = 'freq', kind = 'bar', figsize = (5,5))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df1=df[df.Medal=="Gold"]
df1[df1.Gender=="Women"].Sport.value_counts().head()
# Out:
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64

# %%
df1=df[df.Medal=="Gold"]
df1[df1.Gender=="Women"].Sport.value_counts().head().plot(x = 'Sport', y = 'freq', kind = 'bar', figsize = (5,5))
